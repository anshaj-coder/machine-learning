# %% [markdown]
# <a href="https://colab.research.google.com/github/anshaj-coder/linear-regression/blob/main/decision_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#  Decision Tree

from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt


X = [[0,0], [0,1], [1,0], [1,1]]
y = [0, 1, 1, 0]


clf = DecisionTreeClassifier()
clf.fit(X, y)


a = int(input("Enter first feature (0 or 1): "))
b = int(input("Enter second feature (0 or 1): "))
prediction = clf.predict([[a, b]])
print("Predicted class:", prediction[0])


plt.figure(figsize=(6,4))
plot_tree(clf, filled=True, rounded=True)
plt.show()
# Out:
# Enter first feature (0 or 1): 0
# Enter second feature (0 or 1): 1
# Predicted class: 1
